# %% [markdown]
# <center><h1><b>PROJECT</b></h1></center>

# %%
library(ggplot2)
library(dplyr)
library(stats)
library(sf)
library(geosphere)
library(patchwork)
# Out:
# Caricamento pacchetto: ‘dplyr’
#
#
# I seguenti oggetti sono mascherati da ‘package:stats’:
#
#     filter, lag
#
#
# I seguenti oggetti sono mascherati da ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Linking to GEOS 3.13.0, GDAL 3.10.2, PROJ 9.5.1; sf_use_s2() is TRUE

# %% [markdown]
# ---

# %% [markdown]
# ## GUTHENBERG-RICHTER LAW
# (see wikipedia for more)
# In seismology, the Gutenberg–Richter law[1] (GR law) expresses the relationship between the magnitude and total number of earthquakes in any given region and time period of at least that magnitude.
# $$ log_{10} ⁡ N = a − b \cdot M $$
#
# where N is the number of events having a magnitude ≥ M, a and b are constants, i.e. they are the same for all values of N and M.
# This relationship between event magnitude and frequency of occurrence is remarkably common, although the values of a and b may vary significantly from region to region or over time.
# Some generalization of this formula have been made.
#
# #### PARAMETER b
# The parameter b (commonly referred to as the "b-value") is commonly close to 1.0 in seismically active regions. This means that for a given frequency of magnitude 4.0 or larger events there will be 10 times as many magnitude 3.0 or larger quakes and 100 times as many magnitude 2.0 or larger quakes. There is some variation of b-values in the approximate range of 0.5 to 2 depending on the source environment of the region.[5] A notable example of this is during earthquake swarms when b can become as high as 2.5, thus indicating a very high proportion of small earthquakes to large ones. An earthquake swarm is a sequence of seismic events occurring in a local area within a relatively short period. The time span used to define a swarm varies, but may be days, months, or years. Such an energy release is different from the situation when a major earthquake (main shock) is followed by a series of aftershocks: in earthquake swarms, no single earthquake in the sequence is obviously the main shock. In particular, a cluster of aftershocks occurring after a mainshock is not a swarm. The b-value decrease observed prior to the failure of samples deformed in the laboratory[10] has led to the suggestion that this is a precursor to major macro-failure. Alternatively, a b-value significantly different from 1.0 may suggest a problem with the data set; e.g. it is incomplete or contains errors in calculating magnitude.
#
# #### PARAMETER a
# The a-value represents the total seismicity rate of the region. This is more easily seen when the GR law is expressed in terms of the total number of events:
# $$ N = N_{TOT} \cdot 10^{-bM} $$
# with $N_{TOT} = 10^{a}$ the total number of events (above M=0). Since $10^{a}$ is the total number of events, $10^{-bM}$ must be the probability of those events.
#
# #### OTHER MODELS
# The basic model is the Gutenberg Richter
# (GR) model that states the frequency’s logarithm is linearly
# dependent on the magnitude. However, Dargahi-Noubary
# (1986) and Kagan (1993) suggest that more suitable sta-
# tistical models should be used instead of the GR model for
# the distribution with high magnitudes. Petersen et al. (2007)
# proposed a time-independent model showing that the prob-
# ability of earthquake occurrence follows the Poisson dis-
# tribution. Considering the time of earthquakes, stochastic
# processes, especially Poisson processes, have also been used
# to predict the number of earthquakes. However, the Poisson
# model cannot be sufficient since it has an exponential recur-
# rence time distribution and a constant hazard function. This
# assumes that the probability of observing an earthquake at
# any given time is independent of both elapsed time since
# the last earthquake and its severity. This assumption leads
# only to time-independent seismic hazard estimates. Besides,
# earthquakes are clustered in time and space and their distri-
# bution is over-dispersed compared to the Poisson law. [5]
#
# In recent times, taking into account the seasonality and
# trends of earthquakes, the prediction of the size or mag-
# nitude has been performed in a few studies by time series
# models such as Auto-Regressive Integrated Moving Aver-
# age (ARIMA) and generalized autoregressive conditional
# heteroskedasticity (GARCH).
#
# a NEW BETTER MODEL IS The SSA is a nonparametric
# novel and powerful time series analysis technique incorpo-
# rating classical time series analysis, multivariate statistics,
# multivariate geometry, dynamical systems, and signal pro-
# cessing. This new method can be useful for the prediction of
# the earthquake magnitude in a seismic region.
#
# #### ARIMA MODEL
# ARIMA, also known as Box-Jenkins models, is divided into
# seasonal and non-seasonal models. Non-seasonal Box-Jenkins
# models are generally shown as ARIMA (p, d, q), where
# p is the parameter of the autoregression (AR) model, d is
# the number of difference procedure, and q is the parameter
# of the moving average (MA) model. To perform the analysis processes of the Box-Jenkins
# method, first, care should be taken to ensure that the series
# is free of trend and seasonal fluctuations, that is, the series
# should be stationary. Then, determine the p and q param-
# eters depending on the autocorrelation function and the par-
# tial autocorrelation function graphs and control the model
# parameters’ significance. Lastly, the root mean square error
# criterion (RMSE) is used to selects the best model among
# the models having the white noise error series

# %% [markdown]
# ---

# %% [markdown]
# ## LOADING AND CLEANING DATA DATA
# We took the data from https://earthquake.usgs.gov/ in two parts because there was a limit in the download size.

# %%
df1 = read.table("./data/earthquakes_years_2000_2025.csv", header=TRUE, sep=',')
df2 = read.table("./data/earthquakes_years_1925_2000.csv", header=TRUE, sep=',')
cat("The 1st database has ", nrow(df1), " rows", "\n")
cat("The 2nd database has ", nrow(df2), " rows", "\n")
df = rbind(df1, df2)
cat("The final database has ", nrow(df), " rows", "\n")
# Out:
# The 1st database has  13988  rows
# The 2nd database has  14850  rows
# The final database has  28838  rows

# %% [markdown]
# Meaning of the less obvious comlumns:
# * depth: Depth of the earthquake in kilometers (km).
# * mag: Magnitude of the earthquake
# * magType: Type of magnitude used. (maybe we should confront only earthquake with same magtype?)
# * nst: Number of seismic stations that reported the event.
# * gap: Largest azimuthal gap in station coverage (degrees).
# * dmin: Distance to the nearest station (in degrees).
# * rms: Root mean square of the travel time residuals (in seconds).
# * net: Network that detected the event (e.g., us, ci, hv). It identifies the organization or seismic network responsible.
# * id: The unique identifier for the earthquake event. It’s usually a string combining the net code and a unique event code.
# * updated: Time the event information was last updated.
# * place: Human-readable location (e.g., "10km SE of Town X").
# * type: Type of seismic event (earthquake, quarry blast, etc.). But I only downloaded earthquakes so this column should be useless.
# * horizontalError: Horizontal location error (in km or m).
# * depthError: Error estimate for the depth (in km).
# * magError: Error estimate for the magnitude.
# * magNst: Number of stations used for magnitude calculation.
# * status: Review status of the event (reviewed, automatic). It means whether the data has been automatically generated or manually reviewed by a seismologist.
# * locationSource: Agency that determined the location.
# * magSource: Agency that determined the magnitude.

# %% [markdown]
# Convert the time column to Date format:

# %%
df$time <- as.POSIXct(df$time, format = "%Y-%m-%dT%H:%M:%OSZ", tz = "UTC")

# %%
summary(df)
# Out:
#       time                            latitude       longitude
#  Min.   :1925-02-07 12:14:58.150   Min.   :35.61   Min.   : 4.66
#  1st Qu.:1990-07-11 12:17:33.473   1st Qu.:39.37   1st Qu.:10.98
#  Median :1999-06-07 03:23:02.495   Median :42.74   Median :15.27
#  Mean   :1997-09-22 00:29:15.603   Mean   :42.17   Mean   :14.92
#  3rd Qu.:2004-10-01 01:05:55.349   3rd Qu.:44.44   3rd Qu.:20.01
#  Max.   :2025-06-24 03:04:54.730   Max.   :47.76   Max.   :20.87
#
#      depth             mag          magType               nst
#  Min.   : -2.00   Min.   :2.500   Length:28838       Min.   :  0.00
#  1st Qu.:  8.60   1st Qu.:2.700   Class :character   1st Qu.:  7.00
#  Median : 10.00   Median :3.100   Mode  :character   Median : 14.00
#  Mean   : 15.02   Mean   :3.284                      Mean   : 30.35
#  3rd Qu.: 10.00   3rd Qu.:3.600                      3rd Qu.: 35.00
#  Max.   :522.00   Max.   :7.000                      Max.   :729.00
#                                                      NA's   :16493
#       gap             dmin            rms            net
#  Min.   :  6.5   Min.   :0.014   Min.   :0.000   Length:28838
#  1st Qu.: 73.0   1st Qu.:0.571   1st Qu.:0.760   Class :character
#  Median :127.5   Median :1.003   Median :1.000   Mode  :character
#  Mean   :132.8   Mean   :1.135   Mean   :0.969
#  3rd Qu.:179.8   3rd Qu.:1.586   3rd Qu.:1.200
#  Max.   :349.4   Max.   :5.416   Max.   :2.400
#  NA's   :18768   NA's   :27565   NA's   :12776
#       id              updated             place               type
#  Length:28838       Length:28838       Length:28838       Length:28838
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#
#  horizontalError    depthError        magError         magNst
#  Min.   : 0.000   Min.   : 0.000   Min.   :0.032   Min.   :  1.00
#  1st Qu.: 4.000   1st Qu.: 2.000   1st Qu.:0.083   1st Qu.:  2.00
#  Median : 4.900   Median : 3.600   Median :0.153   Median :  6.00
#  Mean   : 4.934   Mean   : 4.398   Mean   :0.163   Mean   : 13.95
#  3rd Qu.: 5.800   3rd Qu.: 5.600   3rd Qu.:0.202   3rd Qu.: 17.00
#  Max.   :15.200   Max.   :44.500   Max.   :0.790   Max.   :285.00
#  NA's   :27512    NA's   :24877    NA's   :27119   NA's   :24603
#     status          locationSource      magSource
#  Length:28838       Length:28838       Length:28838
#  Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character

# %%
head(df,10)
# Out:
#    time                latitude longitude depth  mag magType nst gap dmin  rms
# 1  2025-06-24 03:04:54 41.4136  19.5656   10.000 4.2 mb      41   56 0.233 0.98
# 2  2025-06-21 14:56:54 38.0214  20.2244   53.184 4.2 mb      20  124 1.591 0.98
# 3  2025-06-21 13:25:52 37.9115  20.1867   10.000 4.5 mb      41  107 1.563 1.14
# 4  2025-06-01 16:44:09 43.1747  17.9562   10.000 4.0 mb      49   31 1.215 0.68
# 5  2025-05-22 22:52:00 42.5041  18.3603   10.000 4.0 mb      33   42 0.670 0.82
# 6  2025-05-20 22:37:03 45.9604  11.1350   11.615 2.7 ml      25   79 0.369 0.60
# 7  2025-05-13 10:07:45 40.8277  14.0646   10.000 4.0 mwr     65  105 0.432 0.45
# 8  2025-05-11 11:46:53 42.9684  18.6709   10.000 4.4 mb      47   37 0.692 0.79
# 9  2025-05-10 04:51:34 38.0915  20.3410   42.571 4.1 mb      36  119 1.553 0.99
# 10 2025-05-08 01:42:59 41.8207  12.7418    9.538 2.7 ml      15  125 0.146 1.22
#    ⋯ updated                  place
# 1  ⋯ 2025-06-24T08:13:22.962Z 7 km N of Shijak, Albania
# 2  ⋯ 2025-06-21T15:51:45.040Z 27 km SW of Lixoúri, Greece
# 3  ⋯ 2025-06-22T11:05:17.735Z 38 km SW of Lixoúri, Greece
# 4  ⋯ 2025-06-22T16:37:44.040Z 8 km ENE of Crnići, Bosnia and Herzegovina
# 5  ⋯ 2025-06-08T22:23:48.661Z 12 km WNW of Igalo, Montenegro
# 6  ⋯ 2025-05-21T13:40:42.272Z 2 km NE of Besenello, Italy
# 7  ⋯ 2025-06-05T13:58:19.046Z 3 km SW of Pozzuoli, Italy
# 8  ⋯ 2025-06-13T05:29:08.040Z 22 km ENE of Bileća, Bosnia and Herzegovina
# 9  ⋯ 2025-05-26T22:31:13.040Z 14 km SW of Lixoúri, Greece
# 10 ⋯ 2025-05-11T08:50:31.086Z 1 km NNE of Montecompatri, Italy
#    type       horizontalError depthError magError magNst status
# 1  earthquake 4.47             1.932     0.110    23     reviewed
# 2  earthquake 2.82            12.614     0.200     9     reviewed
# 3  earthquake 6.06             1.895     0.079    47     reviewed
# 4  earthquake 5.05             1.931     0.150    12     reviewed
# 5  earthquake 2.14             1.927     0.123    18     reviewed
# 6  earthquake 2.28             5.934     0.057    40     reviewed
# 7  earthquake 5.26             1.909     0.093    11     reviewed
# 8  earthquake 4.11             1.932     0.130    17     reviewed
# 9  earthquake 6.39            10.659     0.140    14     reviewed
# 10 earthquake 2.58             6.754     0.066    30     reviewed
#    locationSource magSource
# 1  us             us
# 2  us             us
# 3  us             us
# 4  us             us
# 5  us             us
# 6  us             us
# 7  us             us
# 8  us             us
# 9  us             us
# 10 us             us

# %% [markdown]
# ### CLEANING

# %% [markdown]
# Not a very good dataset, there are many NA values. In particular many columns are almost useless for this (magError, depthError...).
#
# Let's keep only useful columns:

# %%
df_cleaned <- df[, c('time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'id','place', 'locationSource', 'status') ]

# %%
# check for NA values in selected columns:
for (col in 1:length(df_cleaned) ) {
    cat("Number of NA values in column ", col, ": ", sum(is.na(df_cleaned[1])), "\n")
}
# Out:
# Number of NA values in column  1 :  0
# Number of NA values in column  2 :  0
# Number of NA values in column  3 :  0
# Number of NA values in column  4 :  0
# Number of NA values in column  5 :  0
# Number of NA values in column  6 :  0
# Number of NA values in column  7 :  0
# Number of NA values in column  8 :  0
# Number of NA values in column  9 :  0
# Number of NA values in column  10 :  0

# %%
df_cleaned <- df_cleaned %>% filter(grepl("Italy$", place))

head(df_cleaned)
# Out:
#   time                latitude longitude depth  mag magType id
# 1 2025-05-20 22:37:03 45.9604  11.1350   11.615 2.7 ml      us7000q0g6
# 2 2025-05-13 10:07:45 40.8277  14.0646   10.000 4.0 mwr     us7000pyym
# 3 2025-05-08 01:42:59 41.8207  12.7418    9.538 2.7 ml      us7000pxxr
# 4 2025-04-16 01:26:09 37.6250  16.1162   51.185 4.7 mb      us6000q6cn
# 5 2025-03-18 09:01:26 40.6596  15.8360   17.181 4.3 mwr     us6000pzjc
# 6 2025-03-15 20:45:58 38.0732  12.2019   10.000 4.0 mb      us6000pz2t
#   place                              locationSource status
# 1 2 km NE of Besenello, Italy        us             reviewed
# 2 3 km SW of Pozzuoli, Italy         us             reviewed
# 3 1 km NNE of Montecompatri, Italy   us             reviewed
# 4 34 km SSE of Palizzi Marina, Italy us             reviewed
# 5 3 km NE of Potenza, Italy          us             reviewed
# 6 19 km NW of Favignana, Italy       us             reviewed

# %% [markdown]
# ---

# %% [markdown]
# ## Sismic map based on the Gutember-Richter law

# %% [markdown]
# In order to obtain a sismic map based on the Gutember'Richter law we will follow these steps:
# - Divide the Region into Grid Cells
# - Apply the Gutenberg-Richter Formula
#   - Count the number of events above different magnitudes
#   - Fit the G-R law using linear regression on $log_{10}(N)$ vs. $M$
#   - Derive local $a$ and $b$ values
# - Create heat maps:
#   - One showing seismicity rate (the $a$ value)
#   - One showing the relative hazard (via the bb value—lower $b$ means more large earthquakes)

# %%
options(repr.plot.width=7, repr.plot.height=5)
ggplot(df_cleaned, aes(x = longitude, y = latitude)) +
  # let's draw the map outline of Italy using the "maps" package
  borders("world", 
          regions = c("Italy", "Germany", "Switzerland", "France", "Austria", "Slovenia", "Croatia", 
                      "Greece", "Albania", 'Bosnia and Herzegovina', 'Hungary'), 
          , fill = "gray80", colour = "gray10") +
  geom_point(aes(size = mag, color = mag), alpha = 0.3) +
  coord_fixed(xlim = c(5, 19), ylim = c(35, 47.5)) +    #  ensures the aspect ratio is preserved, so the map doesn’t look stretched
  scale_color_viridis_c() +
  labs(title = "Earthquakes in Italy (Mw > 2.5, 1925–2025)",
       x = "Longitude", y = "Latitude", color = "Magnitude", size = "Magnitude") +
  theme_minimal()
# Out:
# plot without title

# %%
# set the values for the grid
lat_grid <- seq(min(df_cleaned$latitude), max(df_cleaned$latitude), 0.25)
lon_grid <- seq(min(df_cleaned$longitude), max(df_cleaned$longitude), 0.25)
mag_values <- seq(2,7,0.1)  # groups of magnitudes => levels of the array to hold the data

# N is a matrix that cointains the number of earthquakes cell by cell
j <- 1:(length(lat_grid)-1)
k <- 1:(length(lon_grid)-1)
#N <- matrix(0, nrow = length(j), ncol = length(k))
i <- 1:(length(mag_values)-1)
N <- array(0, dim = c(length(j), length(k), length(i)))
        
for (lat_i in j){
    for (lon_i in k){
        for (mag_i in i){
        N[lat_i, lon_i, mag_i] <- nrow(df_cleaned[df_cleaned$latitude < lat_grid[lat_i+1] & 
                df_cleaned$latitude >= lat_grid[lat_i] & 
                df_cleaned$longitude < lon_grid[lon_i+1] & 
                df_cleaned$longitude >= lon_grid[lon_i] & 
                df_cleaned$mag >= mag_values[mag_i] , ])
        }
    }
}

# %%
# perform the fit cell by cell
b_values <- matrix(NA, nrow = length(j), ncol = length(k))
a_values <- matrix(NA, nrow = length(j), ncol = length(k))

for (lat_i in j){
  for (lon_i in k){
    counts <- N[lat_i, lon_i, ]
    mags <- mag_values[-length(mag_values)]  # since N uses intervals
    if (sum(counts) >= 10 ) {  # ensure enough data 
      log_N <- log10(rev(cumsum(rev(counts))))
      log_N[!is.finite(log_N)] <- NA  # convert -Inf to NA
      fit <- lm(log_N ~ mags)
      b_values[lat_i, lon_i] <- -coef(fit)[2]
      a_values[lat_i, lon_i] <- coef(fit)[1]
    }
  }
}

# %%
map <- expand.grid(
  lon = lon_grid[-length(lon_grid)] + 0.25,  # center of each cell
  lat = lat_grid[-length(lat_grid)] + 0.25
)

# prepare the data in a dataframe
map$a_value <- as.vector(a_values)
map$b_value <- as.vector(b_values)

# plot the a and b grid 
b_plot <- ggplot(map, aes(x = lon, y = lat, fill = b_value)) +
  borders("world", 
          regions = c("Italy", "Germany", "Switzerland", "France", "Austria", "Slovenia", "Croatia", 
                      "Greece", "Albania", 'Bosnia and Herzegovina', 'Hungary') 
          , fill = "gray80", colour = "gray10", alpha = 0.5) +
  geom_tile(color = NA, na.rm = TRUE) +
  scale_fill_viridis_c(option = "magma", direction = -1, na.value = "transparent", alpha = 0.5, limits = c(0.5, 1.5)) +
  coord_fixed(xlim = c(5, 19), ylim = c(35, 47.5)) +
  labs(title = "b-value Map", x = "Longitude", y = "Latitude", fill = "b-value") +
  theme_minimal()

a_plot <- ggplot(map, aes(x = lon, y = lat, fill = a_value)) +
  # let's draw the map outline of Italy using the "maps" package
  borders("world", 
          regions = c("Italy", "Germany", "Switzerland", "France", "Austria", "Slovenia", "Croatia", 
                      "Greece", "Albania", 'Bosnia and Herzegovina', 'Hungary'), 
          , fill = "gray80", colour = "gray10", alpha = 0.5) +
  geom_tile(color = NA, na.rm = TRUE) +
  scale_fill_viridis_c(option = "inferno", direction = -1, na.value = "transparent", alpha = 0.5) +
  coord_fixed(xlim = c(5, 19), ylim = c(35, 47.5)) +
  labs(title = "a-value Map", x = "Longitude", y = "Latitude", fill = "a-value") +
  theme_minimal()

options(repr.plot.width = 20, repr.plot.height = 5)
a_plot + b_plot
# Out:
# plot without title

# %% [markdown]
# - **Mappa del b-value**: evidenzia aree dove la sismicità è dominata da terremoti piccoli (b > 1) oppure da eventi forti (b < 1). Valori elevati sono tipici degli sciami.
# - **Mappa del a-value**: mostra il livello assoluto di attività sismica. Aree con valori alti hanno molti terremoti, indipendentemente dalla magnitudo.

# %%
# Definisci il periodo di previsione
years <- 20  # ad esempio, 20 anni

# Matrice per contenere le stime 
N_future <- array(NA, dim = c(length(j), length(k), length(i)))

for (lat_i in j){
  for (lon_i in k){
    a <- a_values[lat_i, lon_i]
    b <- b_values[lat_i, lon_i]
    if (!is.na(a) & !is.na(b)){
      for (mag_i in i){
        M <- mag_values[mag_i]
        N_annual <- 10^(a - b * M)
        N_future[lat_i, lon_i, mag_i] <- N_annual * years
      }
    }
  }
}

# %%
#  https://www.usgs.gov/programs/earthquake-hazards/google-earthtmkml-files -> pagina dove trovare il file per il bordo delle placche
# istruzioni: 1) Rinominare il file come .zip; 2) Estrarre il file; 3) Prendere il file .kml;

layers_info <- st_layers("doc.kml")
print(layers_info)
# Out:
# Driver: LIBKML
# Available layers:
#                           layer_name geometry_type features fields crs_name
# 1                   Plate Boundaries                      0     13   WGS 84
# 2                    Plate Interface                   1175     13   WGS 84
# 3 Micro Plates and Major Fault Zones                    221     13   WGS 84
# 4                       Plate Motion                    191     12   WGS 84

# %%
placche <- st_read("doc.kml", layer = "Plate Interface")
# Out:
# Reading layer `Plate Interface' from data source
#   `/home/pira/Documenti/PoD/AdvancedStatistics/Earthquakes_Analysis_Italy/doc.kml'
#   using driver `LIBKML'
# Simple feature collection with 1175 features and 13 fields
# Geometry type: MULTILINESTRING
# Dimension:     XYZ
# Bounding box:  xmin: -180 ymin: -66.163 xmax: 180 ymax: 86.805
# z_range:       zmin: 0 zmax: 0
# Geodetic CRS:  WGS 84

# %%
print(placche)
plot(st_geometry(placche))  # visualizzazione rapida
# Out:
# Simple feature collection with 1175 features and 13 fields
# Geometry type: MULTILINESTRING
# Dimension:     XYZ
# Bounding box:  xmin: -180 ymin: -66.163 xmax: 180 ymax: 86.805
# z_range:       zmin: 0 zmax: 0
# Geodetic CRS:  WGS 84
# First 10 features:
#          id                    Name
# 1  ID_00000 Eurasian:North American
# 2  ID_00001 Eurasian:North American
# 3  ID_00002 Eurasian:North American
# 4  ID_00003 Eurasian:North American
# 5  ID_00004 Eurasian:North American
# 6  ID_00005 Eurasian:North American
# 7  ID_00006 Eurasian:North American
# 8  ID_00007 Eurasian:North American
# 9  ID_00008 Eurasian:North American
# 10 ID_00009 Eurasian:North American
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          description
# 1  <html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n<head>\n<META http-equiv="Content-Type" content="text/html">\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n</head>\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n<td>Eurasian:North American</td>\n</tr>\n<tr>\n<td>\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n<tr>\n<td>NAME</td>\n<td>Eurasian:North American</td>\n</tr>\n<tr bgcolor="#D4E4F3">\n<td>LABEL</td>\n<td>Transform Boundary</td>\n</tr>\n</table>\n</td>\n</tr>\n</table>\n</body>\n</html>\n
# 2  <html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n<head>\n<META http-equiv="Content-Type" content="text/html">\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n</head>\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n<td>Eurasian:North American</td>\n</tr>\n<tr>\n<td>\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n<tr>\n<td>NAME</td>\n<td>Eurasian:North American</td>\n</tr>\n<tr bgcolor="#D4E4F3">\n<td>LABEL</td>\n<td>Divergent Boundary</td>\n</tr>\n</table>\n</td>\n</tr>\n</table>\n</body>\n</html>\n
# 3  <html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n<head>\n<META http-equiv="Content-Type" content="text/html">\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n</head>\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n<td>Eurasian:North American</td>\n</tr>\n<tr>\n<td>\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n<tr>\n<td>NAME</td>\n<td>Eurasian:North American</td>\n</tr>\n<tr bgcolor="#D4E4F3">\n<td>LABEL</td>\n<td>Transform Boundary</td>\n</tr>\n</table>\n</td>\n</tr>\n</table>\n</body>\n</html>\n
# 4  <html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n<head>\n<META http-equiv="Content-Type" content="text/html">\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n</head>\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n<td>Eurasian:North American</td>\n</tr>\n<tr>\n<td>\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n<tr>\n<td>NAME</td>\n<td>Eurasian:North American</td>\n</tr>\n<tr bgcolor="#D4E4F3">\n<td>LABEL</td>\n<td>Divergent Boundary</td>\n</tr>\n</table>\n</td>\n</tr>\n</table>\n</body>\n</html>\n
# 5  <html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n<head>\n<META http-equiv="Content-Type" content="text/html">\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n</head>\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n<td>Eurasian:North American</td>\n</tr>\n<tr>\n<td>\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n<tr>\n<td>NAME</td>\n<td>Eurasian:North American</td>\n</tr>\n<tr bgcolor="#D4E4F3">\n<td>LABEL</td>\n<td>Divergent Boundary</td>\n</tr>\n</table>\n</td>\n</tr>\n</table>\n</body>\n</html>\n
# 6  <html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n<head>\n<META http-equiv="Content-Type" content="text/html">\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n</head>\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n<td>Eurasian:North American</td>\n</tr>\n<tr>\n<td>\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n<tr>\n<td>NAME</td>\n<td>Eurasian:North American</td>\n</tr>\n<tr bgcolor="#D4E4F3">\n<td>LABEL</td>\n<td>Transform Boundary</td>\n</tr>\n</table>\n</td>\n</tr>\n</table>\n</body>\n</html>\n
# 7  <html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n<head>\n<META http-equiv="Content-Type" content="text/html">\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n</head>\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n<td>Eurasian:North American</td>\n</tr>\n<tr>\n<td>\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n<tr>\n<td>NAME</td>\n<td>Eurasian:North American</td>\n</tr>\n<tr bgcolor="#D4E4F3">\n<td>LABEL</td>\n<td>Divergent Boundary</td>\n</tr>\n</table>\n</td>\n</tr>\n</table>\n</body>\n</html>\n
# 8  <html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n<head>\n<META http-equiv="Content-Type" content="text/html">\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n</head>\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n<td>Eurasian:North American</td>\n</tr>\n<tr>\n<td>\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n<tr>\n<td>NAME</td>\n<td>Eurasian:North American</td>\n</tr>\n<tr bgcolor="#D4E4F3">\n<td>LABEL</td>\n<td>Transform Boundary</td>\n</tr>\n</table>\n</td>\n</tr>\n</table>\n</body>\n</html>\n
# 9  <html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n<head>\n<META http-equiv="Content-Type" content="text/html">\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n</head>\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n<td>Eurasian:North American</td>\n</tr>\n<tr>\n<td>\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n<tr>\n<td>NAME</td>\n<td>Eurasian:North American</td>\n</tr>\n<tr bgcolor="#D4E4F3">\n<td>LABEL</td>\n<td>Divergent Boundary</td>\n</tr>\n</table>\n</td>\n</tr>\n</table>\n</body>\n</html>\n
# 10 <html xmlns:fo="http://www.w3.org/1999/XSL/Format" xmlns:msxsl="urn:schemas-microsoft-com:xslt">\n<head>\n<META http-equiv="Content-Type" content="text/html">\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n</head>\n<body style="margin:0px 0px 0px 0px;overflow:auto;background:#FFFFFF;">\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-collapse:collapse;padding:3px 3px 3px 3px">\n<tr style="text-align:center;font-weight:bold;background:#9CBCE2">\n<td>Eurasian:North American</td>\n</tr>\n<tr>\n<td>\n<table style="font-family:Arial,Verdana,Times;font-size:12px;text-align:left;width:100%;border-spacing:0px; padding:3px 3px 3px 3px">\n<tr>\n<td>NAME</td>\n<td>Eurasian:North American</td>\n</tr>\n<tr bgcolor="#D4E4F3">\n<td>LABEL</td>\n<td>Transform Boundary</td>\n</tr>\n</table>\n</td>\n</tr>\n</table>\n</body>\n</html>\n
#    timestamp begin  end  altitudeMode tessellate extrude visibility drawOrder
# 1       <NA>  <NA> <NA> clampToGround         -1       0         -1        NA
# 2       <NA>  <NA> <NA> clampToGround         -1       0         -1        NA
# 3       <NA>  <NA> <NA> clampToGround         -1       0         -1        NA
# 4       <NA>  <NA> <NA> clampToGround         -1       0         -1        NA
# 5       <NA>  <NA> <NA> clampToGround         -1       0         -1        NA
# 6       <NA>  <NA> <NA> clampToGround         -1       0         -1        NA
# 7       <NA>  <NA> <NA> clampToGround         -1       0         -1        NA
# 8       <NA>  <NA> <NA> clampToGround         -1       0         -1        NA
# 9       <NA>  <NA> <NA> clampToGround         -1       0         -1        NA
# 10      <NA>  <NA> <NA> clampToGround         -1       0         -1        NA
#    icon snippet                       geometry
# 1  <NA>         MULTILINESTRING Z ((66.301 ...
# 2  <NA>         MULTILINESTRING Z ((66.544 ...
# 3  <NA>         MULTILINESTRING Z ((46.063 ...
# 4  <NA>         MULTILINESTRING Z ((70.0894...
# 5  <NA>         MULTILINESTRING Z ((46.314 ...
# 6  <NA>         MULTILINESTRING Z ((9.809 8...
# 7  <NA>         MULTILINESTRING Z ((8.938 8...
# 8  <NA>         MULTILINESTRING Z ((4.508 8...
# 9  <NA>         MULTILINESTRING Z ((4.035 8...
# 10 <NA>         MULTILINESTRING Z ((-7.212 ...
# plot without title

# %%
library(ggplot2)
library(reshape2)

# Supponiamo di voler visualizzare i valori di b per magnitudo ≥ 4.0
b_df <- melt(b_values)
colnames(b_df) <- c("lat_index", "lon_index", "b_value")
b_df$lat <- lat_grid[b_df$lat_index]
b_df$lon <- lon_grid[b_df$lon_index]


ggplot() +
  # confini nazionali
  borders("world", 
          regions = c("Italy", "Germany", "Switzerland", "France", "Austria", "Slovenia", "Croatia", 
                      "Greece", "Albania", "Bosnia and Herzegovina", "Hungary"), 
          fill = "gray80", colour = "gray10", alpha = 0) +

  # placche tettoniche
  geom_sf(data = placche, color = "blue", size = 2) +

  # heatmap parametro b
  geom_tile(data = b_df, aes(x = lon, y = lat, fill = b_value), color = NA, na.rm = TRUE) +

  coord_sf(xlim = c(0, 22), ylim = c(35, 47.5), expand = FALSE) +
  scale_fill_viridis_c(option = "inferno", na.value = "transparent", alpha = 0.5) +
  labs(title = "Distribuzione del parametro b in Italia", x = "Longitudine", y = "Latitudine", fill = "b") +
  theme_minimal()

options(repr.plot.width = 10, repr.plot.height = 10)
# Out:
# plot without title

# %%
# Soglia di magnitudo
M_strong <- 5.5
years <- 20

# Matrice per contenere la probabilità
P_strong <- matrix(NA, nrow = length(j), ncol = length(k))

for (lat_i in j){
  for (lon_i in k){
    a <- a_values[lat_i, lon_i]
    b <- b_values[lat_i, lon_i]
    if (!is.na(a) & !is.na(b) & b < 0.8){
      lambda <- 10^(a - b * M_strong) * years
      P_strong[lat_i, lon_i] <- 1 - exp(-lambda)
    }
  }
}

# %%
map$prob <- as.vector(P_strong)

prob_plot <- ggplot(map, aes(x = lon, y = lat, fill = prob)) +
  borders("world", 
          regions = c("Italy", "Germany", "Switzerland", "France", "Austria", "Slovenia", "Croatia", 
                      "Greece", "Albania", 'Bosnia and Herzegovina', 'Hungary'), 
          fill = "gray80", colour = "gray10", alpha = 0.5) +
  geom_tile(color = NA, na.rm = TRUE) +
  scale_fill_viridis_c(option = "plasma", direction = -1, na.value = "transparent", limits = c(0, 1)) +
  coord_fixed(xlim = c(5, 19), ylim = c(35, 47.5)) +
  labs(title = "Probabilità di almeno un terremoto forte (M ≥ 5.5) in 20 anni", 
       x = "Longitudine", y = "Latitudine", fill = "Probabilità") +
  theme_minimal()

prob_plot
# Out:
# plot without title

# %%
mag_range <- which(mag_values >= 4.5 & mag_values <= 5.5)
N_range <- apply(N_future[,,mag_range], c(1,2), sum)
print(N_range)
# Out:
#              [,1]        [,2]        [,3]         [,4]         [,5]        [,6]
#  [1,]          NA          NA          NA           NA           NA          NA
#  [2,]          NA          NA          NA           NA           NA          NA
#  [3,]          NA          NA          NA           NA           NA          NA
#  [4,]          NA          NA          NA           NA           NA          NA
#  [5,]          NA          NA          NA           NA           NA          NA
#  [6,]          NA          NA          NA           NA           NA          NA
#  [7,]          NA          NA          NA           NA           NA          NA
#  [8,]          NA          NA          NA           NA           NA          NA
#  [9,]          NA          NA          NA           NA           NA          NA
# [10,]          NA          NA          NA           NA           NA          NA
# [11,]          NA          NA          NA           NA           NA          NA
# [12,]          NA          NA          NA           NA           NA          NA
# [13,]          NA          NA          NA           NA           NA          NA
# [14,]          NA          NA          NA           NA           NA          NA
# [15,] 635.6495940          NA          NA           NA           NA          NA
# [16,]          NA  114.605983  50.9944823           NA           NA          NA
# [17,]   6.5119504   68.473535 258.0290459           NA           NA          NA
# [18,]          NA          NA          NA           NA           NA          NA
# [19,]  10.9072024          NA          NA           NA           NA          NA
# [20,]          NA    3.600636          NA           NA           NA          NA
# [21,]          NA          NA          NA   10.5468092           NA          NA
# [22,]          NA          NA          NA           NA           NA          NA
# [23,]          NA          NA          NA    3.6006363           NA   3.6006363
# [24,]          NA          NA          NA           NA  11.73406494 114.6059827
# [25,]          NA          NA          NA    3.6006363           NA          NA
# [26,]          NA          NA          NA           NA           NA          NA
# [27,]          NA          NA          NA           NA           NA          NA
# [28,]          NA          NA          NA           NA           NA          NA
# [29,]          NA          NA          NA           NA           NA          NA
# [30,]          NA          NA          NA           NA           NA          NA
# [31,]          NA          NA          NA           NA           NA   3.6006363
# [32,]          NA          NA          NA           NA           NA  17.3078307
# [33,]          NA          NA          NA           NA   2.31931599  11.1508141
# [34,]          NA          NA          NA           NA   4.44716047  63.2281572
# [35,]          NA          NA   0.3651113   11.3469560 142.73060502   0.4030161
# [36,]          NA 1120.068194  38.0166230  271.8388305   7.54393935  18.0302321
# [37,]          NA   20.810533   0.8049081   51.5592229   0.63141854 218.6654436
# [38,]   0.7937037    1.752602   6.8746370  245.5242141 338.99685837 162.9074921
# [39,]          NA          NA   3.0712073 1134.6605350  19.82573439 110.6706223
# [40,]          NA          NA   0.1703288    0.2847604   0.06675872   6.7889276
# [41,]          NA          NA  27.6310490    2.0306428   9.95167393  15.2725079
# [42,]          NA          NA          NA  141.3508360 175.60991031   1.1352857
# [43,]          NA          NA          NA           NA           NA          NA
# [44,]          NA          NA          NA           NA           NA          NA
# [45,]          NA          NA          NA           NA           NA          NA
#              [,7]         [,8]        [,9]       [,10]       [,11]       [,12]
#  [1,]          NA           NA          NA          NA          NA          NA
#  [2,]          NA           NA          NA          NA          NA          NA
#  [3,]          NA           NA          NA          NA          NA          NA
#  [4,]          NA           NA          NA          NA          NA          NA
#  [5,]          NA           NA          NA          NA          NA          NA
#  [6,]          NA           NA          NA          NA          NA          NA
#  [7,]          NA           NA          NA          NA          NA          NA
#  [8,]          NA           NA          NA          NA          NA          NA
#  [9,]          NA           NA          NA          NA          NA          NA
# [10,]          NA           NA          NA          NA          NA          NA
# [11,]          NA  863.8593991          NA          NA          NA          NA
# [12,]          NA           NA          NA          NA          NA          NA
# [13,]          NA           NA          NA          NA          NA          NA
# [14,]          NA           NA          NA          NA  25.6904272          NA
# [15,]          NA           NA          NA          NA          NA          NA
# [16,]          NA           NA          NA          NA          NA          NA
# [17,]          NA           NA          NA          NA          NA          NA
# [18,]          NA           NA          NA          NA          NA          NA
# [19,]          NA           NA          NA  50.9944823          NA          NA
# [20,]          NA           NA          NA          NA 776.6164964          NA
# [21,]          NA           NA          NA          NA          NA          NA
# [22,]          NA           NA          NA          NA          NA          NA
# [23,]          NA           NA          NA          NA          NA          NA
# [24,]          NA           NA          NA          NA          NA          NA
# [25,]          NA           NA          NA          NA          NA          NA
# [26,]          NA           NA          NA          NA          NA          NA
# [27,]          NA           NA          NA          NA          NA          NA
# [28,]          NA           NA          NA          NA          NA          NA
# [29,]          NA           NA          NA          NA          NA          NA
# [30,]          NA           NA          NA          NA          NA          NA
# [31,]  16.7733314 3962.6429625   4.1460844          NA          NA          NA
# [32,]  46.4101092  291.7051328  36.4888216          NA   5.0072646          NA
# [33,]  14.3821925   15.7998489 211.5816952   0.4136305          NA   0.5203886
# [34,]  46.9930394    0.1695601  15.3666236 311.9900620   7.5347180          NA
# [35,]   0.2754571  263.6514068   6.2872191   2.5244130   1.4132345   0.8514315
# [36,]   0.6018532   11.9015001   0.9599343   6.6901021 255.3407286   2.9638442
# [37,]   9.7177516   29.6932391 524.6304284   1.2408399 467.6663439   4.1041005
# [38,]   2.0532470  321.6366045   2.3835639  95.6468025  88.0284205  32.1123876
# [39,]   0.0491984           NA          NA  10.9072024 111.7250390 215.3232461
# [40,]          NA           NA          NA          NA          NA   5.0374649
# [41,] 747.1049182    6.2409042          NA          NA   0.1409512  73.8558279
# [42,]   0.3947446  205.3877533  73.4493350          NA          NA          NA
# [43,]          NA    1.6016938   1.1196666          NA          NA   2.0815497
# [44,]          NA           NA   0.1805230          NA          NA          NA
# [45,]          NA           NA          NA          NA          NA          NA
#             [,13]       [,14]       [,15]       [,16]       [,17]       [,18]
#  [1,]          NA          NA          NA          NA          NA          NA
#  [2,]          NA          NA          NA          NA          NA          NA
#  [3,]          NA          NA          NA          NA          NA          NA
#  [4,]          NA          NA          NA          NA          NA          NA
#  [5,]          NA          NA          NA          NA          NA          NA
#  [6,]          NA          NA          NA          NA          NA          NA
#  [7,]          NA          NA          NA          NA          NA          NA
#  [8,]          NA          NA          NA          NA          NA          NA
#  [9,]          NA          NA          NA          NA          NA          NA
# [10,]          NA          NA          NA          NA          NA          NA
# [11,]          NA          NA          NA          NA          NA          NA
# [12,]          NA          NA          NA          NA          NA          NA
# [13,]          NA          NA          NA          NA  357.876445          NA
# [14,]          NA          NA          NA          NA          NA          NA
# [15,]          NA          NA          NA          NA          NA          NA
# [16,]          NA          NA          NA          NA          NA          NA
# [17,]          NA          NA   6.5119504          NA          NA          NA
# [18,]          NA          NA          NA          NA          NA          NA
# [19,]          NA          NA          NA          NA          NA          NA
# [20,]          NA          NA          NA          NA          NA          NA
# [21,]          NA          NA 514.8033607  829.986181          NA          NA
# [22,]          NA          NA 411.5813210  810.029530          NA          NA
# [23,]          NA          NA          NA  477.448954          NA          NA
# [24,]          NA          NA          NA          NA   25.690427          NA
# [25,]          NA          NA          NA          NA          NA   50.994482
# [26,]          NA          NA          NA          NA          NA          NA
# [27,]          NA          NA          NA          NA          NA          NA
# [28,]          NA          NA          NA          NA          NA  136.282492
# [29,]          NA          NA          NA          NA          NA          NA
# [30,]  215.323246          NA          NA          NA          NA   57.574198
# [31,]          NA          NA          NA  481.053995    9.948306   17.591319
# [32,]          NA          NA          NA  550.754736  314.392253    1.772827
# [33,]          NA  136.947071   0.9569988  117.311490          NA    1.027462
# [34,]          NA    2.627587  73.0061732 1288.094984  448.857251  800.879799
# [35,]    3.331006   82.209875 448.0208933 1879.481170  468.741793  319.822520
# [36,]  383.454840 1200.482509 737.6612749  306.604745 1290.575262 1717.294297
# [37,] 1189.264674  221.283320 254.8283112  611.639930 1156.454458 1804.298172
# [38,]   10.116221    1.492458  98.6180898    7.583537    3.251848   61.082472
# [39,]  199.553009   25.690427   7.1631095    6.700340    3.600636    1.119667
# [40,]  599.345800  532.994799 535.1580446  535.546307  665.636997  160.264576
# [41,]  198.983415   45.205860 149.0344648   79.040510   42.972582 1198.648914
# [42,]          NA          NA   4.8543973    1.016534    2.072544   33.488702
# [43,]          NA          NA          NA    2.510498    5.318348    4.583684
# [44,]          NA          NA  13.3308400  889.774442   29.570018  166.236268
# [45,]          NA          NA          NA          NA  397.427806    2.355513
#             [,19]        [,20]        [,21]       [,22]       [,23]
#  [1,]          NA           NA           NA          NA          NA
#  [2,]          NA           NA           NA          NA   25.690427
#  [3,]          NA           NA           NA          NA          NA
#  [4,]          NA           NA   25.6904272   25.690427          NA
#  [5,]          NA           NA           NA          NA          NA
#  [6,]          NA           NA           NA          NA          NA
#  [7,]          NA           NA           NA          NA    3.600636
#  [8,]          NA           NA           NA   50.994482          NA
#  [9,]          NA           NA           NA          NA  544.731005
# [10,]          NA   50.9944823    6.5119504          NA   38.600833
# [11,]          NA           NA   62.6728111 1118.555237  581.394962
# [12,]          NA           NA           NA          NA  387.246247
# [13,]          NA           NA           NA          NA          NA
# [14,]          NA           NA           NA          NA          NA
# [15,]          NA           NA           NA          NA          NA
# [16,]          NA           NA           NA          NA          NA
# [17,]          NA           NA           NA          NA          NA
# [18,]          NA           NA           NA          NA          NA
# [19,]          NA           NA           NA          NA          NA
# [20,]          NA           NA           NA          NA          NA
# [21,]          NA           NA           NA          NA          NA
# [22,]          NA           NA           NA   17.170761          NA
# [23,]          NA           NA           NA          NA          NA
# [24,]          NA           NA  114.6059827          NA          NA
# [25,]          NA           NA           NA          NA          NA
# [26,]          NA           NA           NA    3.600636          NA
# [27,]          NA           NA           NA          NA          NA
# [28,]   89.586678           NA           NA    7.773154   36.340001
# [29,]          NA           NA           NA  273.274603  882.509799
# [30,]  659.929026    4.1958555   15.7853315          NA  921.064914
# [31,]   86.420854    0.7510283 1758.8717874   17.185246          NA
# [32,]  104.735763  157.8001505   25.1100111   13.776516  231.261987
# [33,]  342.023655   52.8518680  713.5372056  863.277210 1068.695015
# [34,]  593.218737 1359.9585516   64.8199185 1891.179914  717.194995
# [35,]  676.285152  498.6260593 2286.6720767   55.052863 2295.260304
# [36,]  414.413031  651.1392979   18.3637583   69.572092 1244.522252
# [37,] 3733.484206 2919.7315409 1662.8049118   45.936551    5.862079
# [38,]  372.913256  813.9732696  312.8441055    2.081550    3.834797
# [39,]  418.771550           NA   10.9072024          NA    6.511950
# [40,]   97.013805    6.0832696   73.4493350    7.129480  131.851173
# [41,]  180.903849  881.3633112  144.4563868   38.309503   49.285754
# [42,]   97.177503    3.2490332    0.3131291    6.240904  668.533225
# [43,]    8.355672    0.4322700           NA          NA    7.201273
# [44,]   39.875984           NA   13.3308400          NA          NA
# [45,]          NA  410.7050886   76.2218235          NA          NA
#              [,24]       [,25]       [,26]        [,27]        [,28]
#  [1,]           NA   17.170761    3.023042           NA           NA
#  [2,]           NA          NA  347.028065  400.4292467           NA
#  [3,]           NA  114.605983   92.798617  109.9502977           NA
#  [4,] 258.02904592          NA  298.789082  125.7377406           NA
#  [5,]           NA          NA   55.641066   66.2443707           NA
#  [6,]           NA          NA  477.448954  177.2846965           NA
#  [7,]  25.69042722          NA    6.511950   11.6583678 5.616580e+01
#  [8,]           NA          NA          NA           NA 1.776263e+02
#  [9,]           NA  694.328351  177.284697 1977.5463936           NA
# [10,] 132.81773113    7.008682    3.600636           NA           NA
# [11,]   1.91426765  929.621994  546.029178  572.2656246 2.317806e+02
# [12,] 146.01575417 1846.587419  555.692367  588.1385545 1.869796e+01
# [13,]           NA   19.323717    1.263747  900.6813407           NA
# [14,]           NA          NA    3.600636           NA           NA
# [15,]           NA          NA          NA           NA 1.146060e+02
# [16,]           NA          NA          NA  357.8764452 4.151724e+02
# [17,]           NA          NA          NA  509.1164597 4.453773e+02
# [18,]           NA          NA  716.646288  614.7010722 1.141580e+03
# [19,]           NA          NA  357.876445  415.1723970 9.560157e+02
# [20,]           NA          NA          NA           NA 1.409512e-01
# [21,]           NA          NA          NA    0.7650812           NA
# [22,]   0.06412719          NA          NA           NA           NA
# [23,]           NA   10.907202    6.511950           NA           NA
# [24,]           NA  544.731005  137.326850   17.5411920           NA
# [25,]           NA   77.778471  266.022139    0.5155125 2.059693e+02
# [26,]           NA   14.243941    1.721775  580.9368171 1.899466e+02
# [27,]  14.84661953          NA   30.326033  302.8907476 3.590319e+03
# [28,]   5.42920722  359.833533  137.088499  103.8231798 6.782212e+03
# [29,] 755.98144742  144.465944  512.198110 4999.0577122 8.772835e+03
# [30,] 196.39191133  196.961232 5316.657620 5933.0728482 1.402750e+03
# [31,] 336.09255115 1998.617707 1182.021521 1103.2517628 4.197623e+01
# [32,] 986.51152170  808.029021   14.986555  105.2566312 1.938266e+01
# [33,] 217.88582939   81.761143   53.656001  439.5461124 5.052461e+02
# [34,] 204.53397799   90.354665  174.017997   82.4330116 1.922842e+03
# [35,] 674.50882322  360.535139  103.390101           NA 2.569043e+01
# [36,] 588.03304605  390.374336          NA           NA 2.195159e+00
# [37,]  50.99448230   15.750398    6.511950           NA           NA
# [38,]  10.90720239          NA          NA    5.1672281           NA
# [39,] 215.32324607          NA  544.731005    4.6542764           NA
# [40,] 114.60598272   56.618548   23.941671    2.0995023 3.763136e+02
# [41,]   4.69125912   14.950628    9.544670  931.5700463 1.146060e+02
# [42,] 188.59382263 1411.639923    4.721981  580.8357556 6.236714e+02
# [43,]  62.60131164  664.050897 1764.310727 7494.9841149 1.125552e+04
# [44,]  89.58667847  101.187342  608.561870 2665.2090187 6.998794e+01
# [45,]  68.49798755          NA          NA           NA           NA
#              [,29]       [,30]      [,31]        [,32]       [,33]        [,34]
#  [1,]           NA          NA         NA           NA          NA           NA
#  [2,]           NA          NA         NA           NA          NA           NA
#  [3,]           NA          NA         NA           NA          NA           NA
#  [4,]  184.0697598          NA         NA           NA   2.5104976           NA
#  [5,]    6.5119504          NA         NA   86.2920625   6.5119504   58.2784767
#  [6,]           NA          NA         NA           NA 356.2516745  258.0290459
#  [7,]   50.9944823          NA   51.38085           NA   7.7812198    0.4274872
#  [8,]           NA  162.643013   23.57195   14.8466195 330.4021527  141.3508360
#  [9,]           NA  477.481488  511.28064  322.2458869 639.3091953  663.1049453
# [10,]   27.3489418          NA    5.01502  575.5704706   0.0155805  677.4686972
# [11,]  300.3224801 2085.329881         NA  694.5439063          NA  272.6879734
# [12,]  221.1013816 1163.445401  848.17380 2307.7416722 740.6955753 1785.5237485
# [13,]    7.5102117    6.858670  144.22369 1117.1222383 369.3649104 1655.1217739
# [14,]           NA  398.624804  526.08948           NA 827.9484142  511.0900930
# [15,] 1488.5269355  258.029046         NA  357.8764452          NA  159.8071207
# [16,]           NA          NA         NA  484.5790683 357.8764452  179.1733569
# [17,] 1771.7347877  897.385916  343.86174  627.2492862 477.4489536  114.6059827
# [18,]           NA          NA         NA  258.0290459          NA  378.6207102
# [19,]           NA  971.280588         NA  477.4489536          NA           NA
# [20,]  299.7921053  298.789082    6.51195           NA          NA   25.6904272
# [21,]  177.2846965          NA  622.05637   89.5645428   6.5119504    2.0815497
# [22,] 1372.6779200          NA         NA           NA 102.5054396  437.9307532
# [23,]   11.7340649  183.582060    3.21510   44.7829993 933.3143385  967.7119858
# [24,]    6.5119504  340.871395  188.39755  353.3243155  26.2445484  243.8201930
# [25,]  353.2263380  906.037026 3804.63331   45.1543761          NA 1380.4302485
# [26,]  388.8715369   56.073196 1284.67387    0.4342862          NA   92.6567867
# [27,] 2200.7653742   24.657613  317.03182   79.5716361  17.1707608           NA
# [28,] 1524.6563376   25.690427   62.24033  167.4632238          NA           NA
# [29,]   70.9571196  311.598346   11.65837  136.2824921   6.5119504    6.5119504
# [30,] 1598.1606480  175.244056  250.64324  339.9221364          NA           NA
# [31,]  367.9204694   77.124322 1648.36881    2.0815497 193.3584011   56.4193835
# [32,]  471.4938756 1181.015486   55.64107   17.1707608  50.9944823           NA
# [33,] 1951.3488347    8.633967   15.76016           NA          NA           NA
# [34,]  213.0360632 1243.361644         NA           NA          NA           NA
# [35,]   14.8466195    6.511950         NA           NA          NA           NA
# [36,]           NA          NA         NA           NA          NA           NA
# [37,]           NA          NA         NA           NA          NA           NA
# [38,]           NA          NA         NA           NA          NA           NA
# [39,]           NA          NA         NA           NA          NA           NA
# [40,]    0.9722543          NA         NA           NA          NA           NA
# [41,]    1.4786092    2.081550         NA           NA          NA           NA
# [42,]   33.1655275   46.837150         NA           NA          NA           NA
# [43,]  233.4840615  103.305649         NA           NA          NA           NA
# [44,]  577.3265251          NA         NA           NA          NA           NA
# [45,]           NA          NA         NA           NA          NA           NA
#             [,35]      [,36]        [,37]       [,38]       [,39]        [,40]
#  [1,]          NA         NA           NA          NA          NA           NA
#  [2,]          NA         NA           NA          NA          NA           NA
#  [3,]          NA   43.97279  114.6059827 1084.615459          NA           NA
#  [4,]    0.432270  215.32325    0.9569988    7.201273  415.172397           NA
#  [5,]  344.272706         NA           NA  215.323246    7.008682           NA
#  [6,]  656.484167         NA   30.1355472          NA  397.082869   11.7340649
#  [7,]  232.297921  159.85526 1446.2146647  319.347233  197.098528   33.5058367
#  [8,]  300.401757  763.16447  177.5958983 1053.035598    3.986279  420.5229512
#  [9,]  562.969264  932.88198  279.7858518   31.059500  175.893492  142.8027056
# [10,]  879.435617  138.25284  401.6019170  309.589040 1384.006124    0.2400659
# [11,] 2863.161055  336.68506  235.8969879  767.111539   94.575878   44.7170593
# [12,] 1338.657155 1291.31798 2109.7752040  639.527353  337.483415  298.2761776
# [13,] 1009.544386 1911.81774  810.4131996  465.938103 1935.782730  614.8436499
# [14,]  114.605983 1511.95305 1127.7864274  527.805993  435.608785    8.6203605
# [15,]  471.635209 1559.33415 2234.6325433  549.512849    5.463025 1067.4797463
# [16,]  824.048958 1222.79627 1425.6039649  514.308307   24.962724   84.7536147
# [17,]  450.917386 1306.03981 1664.6800180 1261.622556 1003.721518  398.4657567
# [18,]  445.254661  238.28113 1526.4238581 1164.921475 1421.413752  323.7103409
# [19,]  863.463284         NA  177.2846965   46.169021  266.510443           NA
# [20,]  483.257603  293.05930  645.6825767  392.996455 1416.614264  113.1507676
# [21,]  926.311835 1971.07617 3356.8995220 2280.266202  454.741158  258.0290459
# [22,] 1609.324338 4332.46354 4901.8295043  178.345997  299.428096           NA
# [23,] 3244.996421  449.84979           NA   12.240053   16.773331    2.6234840
# [24,]  153.968175         NA   18.4137969 2747.356031          NA   89.5866785
# [25,] 3060.753268  147.70594  198.7012310 1474.786967 1037.487991  312.8433872
# [26,]  261.807385  433.11459  554.6532243  527.787672   30.931781  589.7088512
# [27,]    3.600636  428.97384  636.6002884  103.390101 1127.124438  357.8764452
# [28,]          NA  951.27862  132.1682507  219.052432 1464.089154    3.6006363
# [29,]          NA  114.60598           NA          NA          NA           NA
# [30,]    7.510212         NA           NA          NA          NA           NA
# [31,]          NA         NA           NA          NA          NA           NA
# [32,]          NA         NA           NA          NA          NA           NA
# [33,]          NA         NA           NA          NA          NA           NA
# [34,]          NA         NA           NA          NA          NA           NA
# [35,]          NA         NA           NA          NA          NA           NA
# [36,]          NA         NA           NA          NA          NA           NA
# [37,]          NA         NA           NA          NA          NA           NA
# [38,]          NA         NA           NA          NA          NA           NA
# [39,]          NA         NA           NA          NA          NA           NA
# [40,]          NA         NA           NA          NA          NA           NA
# [41,]          NA         NA           NA          NA          NA           NA
# [42,]          NA         NA           NA          NA          NA           NA
# [43,]          NA         NA           NA          NA          NA           NA
# [44,]          NA         NA           NA          NA          NA           NA
# [45,]          NA         NA           NA          NA          NA           NA
#             [,41]       [,42]      [,43]       [,44]      [,45]      [,46]
#  [1,]          NA  215.323246         NA          NA         NA         NA
#  [2,]  17.1707608          NA  357.87645   25.690427         NA         NA
#  [3,]          NA          NA         NA          NA         NA         NA
#  [4,]          NA          NA         NA          NA         NA         NA
#  [5,] 183.5820604          NA         NA          NA         NA         NA
#  [6,]  56.3353670 1372.677920         NA          NA         NA         NA
#  [7,]  50.9944823  412.939902  144.91309          NA         NA         NA
#  [8,] 147.3976479  391.254864  347.18999          NA         NA         NA
#  [9,] 249.2573678  183.582060         NA   10.907202         NA  10.907202
# [10,] 258.0290459   25.690427         NA          NA         NA         NA
# [11,] 349.7657100          NA   38.60083  177.284697         NA         NA
# [12,]          NA    5.037465 1566.88115   35.616422 1460.47562         NA
# [13,]   4.2151117  278.158982  661.15119  485.588266         NA  91.077565
# [14,] 369.0497629  350.991701  423.63151  969.873297  195.29874 155.849901
# [15,] 321.0684025  631.402542  724.58654   71.797505  163.29749  50.994482
# [16,] 191.3518920  172.889829  404.03687  407.125000         NA   1.119667
# [17,] 156.0802592 1055.567642  299.42810  357.876445         NA         NA
# [18,]          NA          NA   28.39824          NA  215.32325         NA
# [19,]   0.3917831          NA         NA   14.243941         NA         NA
# [20,]  41.9236417   25.690427         NA          NA         NA         NA
# [21,]   4.2308230          NA         NA          NA         NA 215.323246
# [22,]          NA          NA         NA          NA         NA  25.690427
# [23,]          NA          NA         NA          NA         NA         NA
# [24,]          NA          NA         NA 1345.331369   34.34152   6.511950
# [25,] 512.8469390          NA         NA    3.600636         NA         NA
# [26,] 177.2846965   50.994482         NA          NA         NA         NA
# [27,]  72.9170140          NA         NA          NA         NA         NA
# [28,]          NA          NA         NA          NA         NA         NA
# [29,]          NA          NA         NA          NA         NA         NA
# [30,]          NA          NA         NA          NA         NA         NA
# [31,]          NA          NA         NA          NA         NA         NA
# [32,]          NA          NA         NA          NA         NA         NA
# [33,]          NA          NA         NA          NA         NA         NA
# [34,]          NA          NA         NA          NA         NA         NA
# [35,]          NA          NA         NA          NA         NA         NA
# [36,]          NA          NA         NA          NA         NA         NA
# [37,]          NA          NA         NA          NA         NA         NA
# [38,]          NA          NA         NA          NA         NA         NA
# [39,]          NA          NA         NA          NA         NA         NA
# [40,]          NA          NA         NA          NA         NA         NA
# [41,]          NA          NA         NA          NA         NA         NA
# [42,]          NA          NA         NA          NA         NA         NA
# [43,]          NA          NA         NA          NA         NA         NA
# [44,]          NA          NA         NA          NA         NA         NA
# [45,]          NA          NA         NA          NA         NA         NA
#            [,47]      [,48]    [,49]    [,50]
#  [1,]         NA 215.323246       NA       NA
#  [2,] 863.859399         NA       NA       NA
#  [3,]         NA         NA       NA       NA
#  [4,]         NA         NA       NA       NA
#  [5,]         NA         NA       NA       NA
#  [6,]         NA  11.734065       NA       NA
#  [7,]         NA 114.605983       NA       NA
#  [8,] 177.284697         NA       NA       NA
#  [9,] 215.323246         NA       NA       NA
# [10,]  50.994482         NA       NA       NA
# [11,]   6.511950  68.473535       NA       NA
# [12,]   6.511950   3.600636       NA       NA
# [13,] 347.501642  10.907202       NA       NA
# [14,]         NA         NA       NA       NA
# [15,]         NA         NA       NA       NA
# [16,]         NA         NA 1086.359 558.1634
# [17,]         NA         NA       NA 419.9275
# [18,]         NA         NA       NA       NA
# [19,]         NA         NA       NA       NA
# [20,]         NA         NA       NA       NA
# [21,]         NA         NA       NA       NA
# [22,]         NA  25.690427       NA       NA
# [23,]         NA         NA       NA       NA
# [24,]   3.600636         NA       NA       NA
# [25,]  25.690427         NA       NA       NA
# [26,]         NA         NA       NA       NA
# [27,]         NA         NA       NA       NA
# [28,]         NA         NA       NA       NA
# [29,]         NA         NA       NA       NA
# [30,]         NA         NA       NA       NA
# [31,]         NA         NA       NA       NA
# [32,]         NA         NA       NA       NA
# [33,]         NA         NA       NA       NA
# [34,]         NA         NA       NA       NA
# [35,]         NA         NA       NA       NA
# [36,]         NA         NA       NA       NA
# [37,]         NA         NA       NA       NA
# [38,]         NA         NA       NA       NA
# [39,]         NA         NA       NA       NA
# [40,]         NA         NA       NA       NA
# [41,]         NA         NA       NA       NA
# [42,]         NA         NA       NA       NA
# [43,]         NA         NA       NA       NA
# [44,]         NA         NA       NA       NA
# [45,]         NA         NA       NA       NA

# %%
# How many events we expect in each region (cell) ? 
years <- 50
M_target <- 5.5
N_M <- 10^(a_values - b_values * M_target) / years
N_M
# Out:
#       [,1]         [,2]         [,3]         [,4]         [,5]
#  [1,]           NA           NA           NA           NA           NA
#  [2,]           NA           NA           NA           NA           NA
#  [3,]           NA           NA           NA           NA           NA
#  [4,]           NA           NA           NA           NA           NA
#  [5,]           NA           NA           NA           NA           NA
#  [6,]           NA           NA           NA           NA           NA
#  [7,]           NA           NA           NA           NA           NA
#  [8,]           NA           NA           NA           NA           NA
#  [9,]           NA           NA           NA           NA           NA
# [10,]           NA           NA           NA           NA           NA
# [11,]           NA           NA           NA           NA           NA
# [12,]           NA           NA           NA           NA           NA
# [13,]           NA           NA           NA           NA           NA
# [14,]           NA           NA           NA           NA           NA
# [15,] 3.096310e-02           NA           NA           NA           NA
# [16,]           NA 4.886212e-03 1.894233e-03           NA           NA
# [17,] 1.640693e-04 2.677076e-03 1.251613e-02           NA           NA
# [18,]           NA           NA           NA           NA           NA
# [19,] 3.043736e-04           NA           NA           NA           NA
# [20,]           NA 8.036038e-05           NA           NA           NA
# [21,]           NA           NA           NA 2.084383e-04           NA
# [22,]           NA           NA           NA           NA           NA
# [23,]           NA           NA           NA 8.036038e-05           NA
# [24,]           NA           NA           NA           NA 2.734195e-04
# [25,]           NA           NA           NA 8.036038e-05           NA
# [26,]           NA           NA           NA           NA           NA
# [27,]           NA           NA           NA           NA           NA
# [28,]           NA           NA           NA           NA           NA
# [29,]           NA           NA           NA           NA           NA
# [30,]           NA           NA           NA           NA           NA
# [31,]           NA           NA           NA           NA           NA
# [32,]           NA           NA           NA           NA           NA
# [33,]           NA           NA           NA           NA 2.602867e-05
# [34,]           NA           NA           NA           NA 8.000561e-05
# [35,]           NA           NA 1.760764e-06 7.416176e-05 2.625162e-03
# [36,]           NA 5.046116e-02 3.381574e-04 4.371301e-03 7.038786e-05
# [37,]           NA 2.977590e-04 5.041366e-06 7.995189e-04 3.799442e-06
# [38,] 8.149097e-06 1.123055e-05 8.219333e-05 5.968675e-03 8.451641e-03
# [39,]           NA           NA 3.793972e-05 5.947233e-02 2.862771e-04
# [40,]           NA           NA 1.271583e-06 2.201675e-06 3.453650e-07
# [41,]           NA           NA 4.338303e-04 1.642624e-05 1.453427e-04
# [42,]           NA           NA           NA 5.833235e-03 7.055674e-03
# [43,]           NA           NA           NA           NA           NA
# [44,]           NA           NA           NA           NA           NA
# [45,]           NA           NA           NA           NA           NA
#       [,6]         [,7]         [,8]         [,9]         [,10]        [,11]
#  [1,]           NA           NA           NA           NA           NA ⋯
#  [2,]           NA           NA           NA           NA           NA ⋯
#  [3,]           NA           NA           NA           NA           NA ⋯
#  [4,]           NA           NA           NA           NA           NA ⋯
#  [5,]           NA           NA           NA           NA           NA ⋯
#  [6,]           NA           NA           NA           NA           NA ⋯
#  [7,]           NA           NA           NA           NA           NA ⋯
#  [8,]           NA           NA           NA           NA           NA ⋯
#  [9,]           NA           NA           NA           NA           NA ⋯
# [10,]           NA           NA           NA           NA           NA ⋯
# [11,]           NA           NA 4.986728e-02           NA           NA ⋯
# [12,]           NA           NA           NA           NA           NA ⋯
# [13,]           NA           NA           NA           NA           NA ⋯
# [14,]           NA           NA           NA           NA           NA ⋯
# [15,]           NA           NA           NA           NA           NA ⋯
# [16,]           NA           NA           NA           NA           NA ⋯
# [17,]           NA           NA           NA           NA           NA ⋯
# [18,]           NA           NA           NA           NA           NA ⋯
# [19,]           NA           NA           NA           NA 1.894233e-03 ⋯
# [20,]           NA           NA           NA           NA           NA ⋯
# [21,]           NA           NA           NA           NA           NA ⋯
# [22,]           NA           NA           NA           NA           NA ⋯
# [23,] 8.036038e-05           NA           NA           NA           NA ⋯
# [24,] 4.886212e-03           NA           NA           NA           NA ⋯
# [25,]           NA           NA           NA           NA           NA ⋯
# [26,]           NA           NA           NA           NA           NA ⋯
# [27,]           NA           NA           NA           NA           NA ⋯
# [28,]           NA           NA           NA           NA           NA ⋯
# [29,]           NA           NA           NA           NA           NA ⋯
# [30,]           NA           NA           NA           NA           NA ⋯
# [31,] 8.036038e-05 3.940556e-04 2.118363e-01 7.695107e-05           NA ⋯
# [32,] 2.666549e-04 9.667845e-04 1.125790e-02 1.000986e-03           NA ⋯
# [33,] 1.127427e-04 2.250097e-04 2.858615e-04 5.793520e-03 2.214350e-06 ⋯
# [34,] 1.091489e-03 7.807284e-04 8.944547e-07 2.261343e-04 8.552977e-03 ⋯
# [35,] 2.183722e-06 1.808921e-06 4.644132e-03 6.682450e-05 2.635967e-05 ⋯
# [36,] 3.648231e-04 7.751671e-06 2.014237e-04 6.724035e-06 7.422405e-05 ⋯
# [37,] 5.634309e-03 1.721898e-04 7.949261e-04 1.372881e-02 1.089009e-05 ⋯
# [38,] 6.228834e-03 2.894894e-05 1.224982e-02 3.711836e-05 2.925431e-03 ⋯
# [39,] 2.982601e-03 2.606218e-07           NA           NA 3.043736e-04 ⋯
# [40,] 9.515432e-05           NA           NA           NA           NA ⋯
# [41,] 3.365556e-04 3.737323e-02 1.023341e-04           NA           NA ⋯
# [42,] 1.481211e-05 1.875747e-06 7.573548e-03 2.508969e-03           NA ⋯
# [43,]           NA           NA 2.582327e-05 1.525363e-05           NA ⋯
# [44,]           NA           NA           NA 1.741307e-06           NA ⋯
# [45,]           NA           NA           NA           NA           NA ⋯
#       [,12]        [,13]        [,14]        [,15]        [,16]
#  [1,]           NA 1.015672e-02           NA           NA          NA
#  [2,] 5.228459e-04           NA 0.0182368799 8.434736e-04          NA
#  [3,]           NA           NA           NA           NA          NA
#  [4,]           NA           NA           NA           NA          NA
#  [5,] 8.045625e-03           NA           NA           NA          NA
#  [6,] 1.691565e-03 8.418175e-02           NA           NA          NA
#  [7,] 1.894233e-03 1.763978e-02 0.0056264155           NA          NA
#  [8,] 4.447881e-03 1.479945e-02 0.0160782864           NA          NA
#  [9,] 9.213366e-03 8.045625e-03           NA 3.043736e-04          NA
# [10,] 1.251613e-02 8.434736e-04           NA           NA          NA
# [11,] 1.264355e-02           NA 0.0011277447 8.110804e-03          NA
# [12,]           NA 9.643867e-05 0.0830164539 8.856531e-04 0.082360973
# [13,] 7.335492e-05 9.854713e-03 0.0329331190 2.020506e-02          NA
# [14,] 1.108436e-02 1.194776e-02 0.0154540426 3.946656e-02 0.007986211
# [15,] 8.102507e-03 2.345043e-02 0.0261212234 1.967129e-03 0.006297451
# [16,] 5.266443e-03 4.295092e-03 0.0125477771 1.704747e-02          NA
# [17,] 5.738030e-03 4.398871e-02 0.0137622934 1.823688e-02          NA
# [18,]           NA           NA 0.0008265405           NA 0.010156722
# [19,] 4.262499e-06           NA           NA 3.450653e-04          NA
# [20,] 1.143026e-03 8.434736e-04           NA           NA          NA
# [21,] 6.326082e-05           NA           NA           NA          NA
# [22,]           NA           NA           NA           NA          NA
# [23,]           NA           NA           NA           NA          NA
# [24,]           NA           NA           NA 7.966408e-02 0.001045692
# [25,] 2.677479e-02           NA           NA 8.036038e-05          NA
# [26,] 8.110804e-03 1.894233e-03           NA           NA          NA
# [27,] 1.617187e-03           NA           NA           NA          NA
# [28,]           NA           NA           NA           NA          NA
# [29,]           NA           NA           NA           NA          NA
# [30,]           NA           NA           NA           NA          NA
# [31,]           NA           NA           NA           NA          NA
# [32,]           NA           NA           NA           NA          NA
# [33,]           NA           NA           NA           NA          NA
# [34,]           NA           NA           NA           NA          NA
# [35,]           NA           NA           NA           NA          NA
# [36,]           NA           NA           NA           NA          NA
# [37,]           NA           NA           NA           NA          NA
# [38,]           NA           NA           NA           NA          NA
# [39,]           NA           NA           NA           NA          NA
# [40,]           NA           NA           NA           NA          NA
# [41,]           NA           NA           NA           NA          NA
# [42,]           NA           NA           NA           NA          NA
# [43,]           NA           NA           NA           NA          NA
# [44,]           NA           NA           NA           NA          NA
# [45,]           NA           NA           NA           NA          NA
#       [,17]        [,18]        [,19]        [,20]      [,21]
#  [1,]           NA           NA 1.015672e-02         NA         NA
#  [2,]           NA 4.986728e-02           NA         NA         NA
#  [3,]           NA           NA           NA         NA         NA
#  [4,]           NA           NA           NA         NA         NA
#  [5,]           NA           NA           NA         NA         NA
#  [6,]           NA           NA 2.734195e-04         NA         NA
#  [7,]           NA           NA 4.886212e-03         NA         NA
#  [8,]           NA 8.110804e-03           NA         NA         NA
#  [9,] 3.043736e-04 1.015672e-02           NA         NA         NA
# [10,]           NA 1.894233e-03           NA         NA         NA
# [11,]           NA 1.640693e-04 2.677076e-03         NA         NA
# [12,]           NA 1.640693e-04 8.036038e-05         NA         NA
# [13,] 3.123021e-03 1.393443e-02 3.043736e-04         NA         NA
# [14,] 5.745178e-03           NA           NA         NA         NA
# [15,] 1.894233e-03           NA           NA         NA         NA
# [16,] 1.525363e-05           NA           NA 0.05660981 0.02104734
# [17,]           NA           NA           NA         NA 0.01907279
# [18,]           NA           NA           NA         NA         NA
# [19,]           NA           NA           NA         NA         NA
# [20,]           NA           NA           NA         NA         NA
# [21,] 1.015672e-02           NA           NA         NA         NA
# [22,] 8.434736e-04           NA 8.434736e-04         NA         NA
# [23,]           NA           NA           NA         NA         NA
# [24,] 1.640693e-04 8.036038e-05           NA         NA         NA
# [25,]           NA 8.434736e-04           NA         NA         NA
# [26,]           NA           NA           NA         NA         NA
# [27,]           NA           NA           NA         NA         NA
# [28,]           NA           NA           NA         NA         NA
# [29,]           NA           NA           NA         NA         NA
# [30,]           NA           NA           NA         NA         NA
# [31,]           NA           NA           NA         NA         NA
# [32,]           NA           NA           NA         NA         NA
# [33,]           NA           NA           NA         NA         NA
# [34,]           NA           NA           NA         NA         NA
# [35,]           NA           NA           NA         NA         NA
# [36,]           NA           NA           NA         NA         NA
# [37,]           NA           NA           NA         NA         NA
# [38,]           NA           NA           NA         NA         NA
# [39,]           NA           NA           NA         NA         NA
# [40,]           NA           NA           NA         NA         NA
# [41,]           NA           NA           NA         NA         NA
# [42,]           NA           NA           NA         NA         NA
# [43,]           NA           NA           NA         NA         NA
# [44,]           NA           NA           NA         NA         NA
# [45,]           NA           NA           NA         NA         NA
